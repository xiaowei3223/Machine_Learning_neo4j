# %% [markdown]
# # Recommendations: Part 2
#
# In the 2nd part of our recommendations exercise, you will use the PageRank algorithm to make article recommendations to an author.
# Execute the code to import the libraries (remember to unset Reset all runtimes before running):
# 在我们推荐练习的第二部分中，您将使用PageRank算法向作者推荐文章。
# 执行代码导入库(记得在运行前取消设置重置所有运行时):

# %%
from py2neo import Graph
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

plt.style.use("fivethirtyeight")
pd.set_option("display.float_format", lambda x: '% 3f' % x)
pd.set_option("display.max_colwidth",100)
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %% [markdown]
# Next, create a connection to your Neo4j Sandbox, just as you did previously when you set up your environment.
# 接下来，创建到Neo4j沙箱的连接，就像之前设置环境时所做的一样。
#
# <div align="left">
#     <img src="images/sandbox-citations.png" alt="Citation Sandbox"/>
# </div>
#
# Update the cell below to use the IP Address, Bolt Port, and Password, as you did previously.
# 像前面一样，更新下面的单元格，使用IP地址、Bolt端口和密码。

# %%
# Change the line of code below to use the IP Address, Bolt Port,  and Password of your Sandbox.
# graph = Graph("<Bolt URL>", auth=("neo4j", "<Password>")) 
 
graph = Graph("bolt://100.25.48.12:37028", auth=("neo4j", "auto-development-gunnery"))

# %% [markdown]
# ## PageRank
#
# PageRank is an algorithm that measures the transitive influence or connectivity of nodes. It can be computed by either iteratively distributing one node’s rank (originally based on degree) over its neighbors or by randomly traversing the graph and counting the frequency of hitting each node during these walks.
# PageRank是一种度量节点间传递影响或连通性的算法。它可以通过在相邻节点上迭代分配一个节点的秩(最初基于度)来计算，也可以通过随机遍历图并计算在这些遍历过程中击中每个节点的频率来计算。
#
# Run this PageRank code over the whole graph to find out the most influential article in terms of citations:
# 在整个图表上运行这个PageRank代码，找出在引用方面最有影响力的文章:

# %%
query = """
CALL algo.pageRank('Article', 'CITED')
"""

graph.run(query).data()
# Out:
# [{'nodes': 51956,
#   'iterations': 20,
#   'loadMillis': 174,
#   'computeMillis': 40,
#   'writeMillis': 222,
#   'dampingFactor': 0.85,
#   'write': True,
#   'writeProperty': 'pagerank'}]

# %% [markdown]
# This query stores a 'pagerank' property on each node. Execute this code to view the most influential articles:
# 该查询在每个节点上存储一个“pagerank”属性。执行此代码查看最有影响力的文章:

# %%
query = """
MATCH (a:Article)
RETURN a.title as article,
       a.pagerank as score
ORDER BY score DESC 
LIMIT 10
"""
graph.run(query).to_data_frame()
# Out:
#                                                                                              article  \
# 0                             A method for obtaining digital signatures and public-key cryptosystems
# 1                                                       Secure communications over insecure channels
# 2                                                                                         Rough sets
# 3                                                        An axiomatic basis for computer programming
# 4  Pastry: Scalable, Decentralized Object Location, and Routing for Large-Scale Peer-to-Peer Systems
# 5                              SCRIBE: The Design of a Large-Scale Event Notification Infrastructure
# 6                                     A field study of the software design process for large systems
# 7                                                  Productivity factors and programming environments
# 8                                                        Analyzing medium-scale software development
# 9                                                                A Calculus of Communicating Systems
#
#        score
# 0  93.943105
# 1  79.869224
# 2  25.609092
# 3  23.029374
# 4  21.469550
# 5  19.486296
# 6  19.028154
# 7  18.499351
# 8  16.452748
# 9  15.430588

# %% [markdown]
# ## Personalized PageRank
#
# Personalized PageRank is a variant of PageRank that allows us to find influential nodes based on a set of source nodes.
# 个性化PageRank是PageRank的一个变体，它允许我们基于一组源节点找到有影响力的节点。
#
# For example, rather than finding the overall most influential articles, we could instead, find the most influential articles with respect to a given author.
# Execute this code to use a personalized PageRank algorithm:
# 例如，我们不需要找出总体上最有影响力的文章，相反，我们可以找到给定作者的最有影响力的文章。执行此代码使用个性化的PageRank算法:

# %%
query ="""
MATCH (a:Author {name:$author})<-[:AUTHOR]-(article)-[:CITED]->(other)
WITH collect(article) + collect(other) AS sourceNodes
CALL algo.pageRank.stream("Article", "CITED", {sourceNodes: sourceNodes})
YIELD nodeId, score
RETURN algo.getNodeById(nodeId).title AS article, score
ORDER BY score DESC
LIMIT 10
"""

author_name = "Peter G. Neumann"
graph.run(query, {"author":author_name}).to_data_frame()
# Out:
#                                                                          article  \
# 0                    A technique for software module specification with examples
# 1         A messy state of the union: taming the composite state machines of TLS
# 2                                                     Crypto policy perspectives
# 3  Risks of automation: a cautionary total-system perspective of our cyberfuture
# 4                                                             The foresight saga
# 5                                                              Risks of e-voting
# 6                                                    Public interest and the NII
# 7                                              Password security: a case history
# 8                                  The challenges of partially automated driving
# 9                        Proof techniques for hierarchically structured programs
#
#       score
# 0  0.358528
# 1  0.331688
# 2  0.277500
# 3  0.277500
# 4  0.277500
# 5  0.277500
# 6  0.277500
# 7  0.277500
# 8  0.267938
# 9  0.248436

# %% [markdown]
# ## Topic Sensitive Search
#
# You can also use Personalized PageRank to do 'Topic Specific PageRank'.
# 你也可以使用个性化的PageRank来做“特定主题的PageRank”。
#
# When an author is searching for articles to read, they want that search to take themselves as authors into account. Two authors using the same search term would expect to see different results depending on their area of research.
# 当作者在搜索要阅读的文章时，他们希望将自己作为作者考虑在内。使用相同搜索词的两位作者希望根据他们的研究领域看到不同的结果。
#
# Create a full text search index on the 'title' and 'abstract' properties of all nodes that have the label 'Article' by executing this code:
# 执行以下代码，在标签为“Article”的所有节点的“title”和“abstract”属性上创建全文搜索索引:

# %%
query = """
    CALL db.index.fulltext.createNodeIndex('articles', ['Article'], ['title', 'abstract'])
"""
graph.run(query).data()

# %% [markdown]
# Check that the full text index has been created by running the following query:
# 检查全文索引是否已通过运行以下查询创建:

# %%
query = """
CALL db.indexes()
YIELD description, indexName, tokenNames, properties, state, type, progress
WHERE type = "node_fulltext"
RETURN *
"""
graph.run(query).to_data_frame()
# Out:
#                               description indexName    progress  \
# 0  INDEX ON NODE:Article(title, abstract)  articles  100.000000
#
#           properties   state tokenNames           type
# 0  [title, abstract]  ONLINE  [Article]  node_fulltext

# %% [markdown]
# You can search the full text index like this:
# 你可以这样搜索全文索引:

# %%
query = """
CALL db.index.fulltext.queryNodes("articles", "open source")
YIELD node, score
RETURN node.title, score, [(author)<-[:AUTHOR]-(node) | author.name] AS authors
LIMIT 10
"""

graph.run(query).to_data_frame()
# Out:
#                                                                                authors  \
# 0                         [Rob Miller, Dean Nelson, Pankaj K. Garg, Jamie Dinkelacker]
# 1  [Walt Scacchi, Joseph Feller, Brian Fitzgerald, Krishna K Lakhani, Scott A. Hissam]
# 2                                                         [Alan W. Brown, Grady Booch]
# 3                                                                    [Roy T. Fielding]
# 4                                                                    [Susan L. Graham]
# 5                                     [Stefan Baldi, Anett Mehler-Bicher, Hauke Heier]
# 6                                                                   [Pamela Samuelson]
# 7                                                             [LiGuo Huang, Zeheng Li]
# 8                                                     [Jaap-Henk Hoepman, Bart Jacobs]
# 9                                                                    [Robert L. Glass]
#
#                                                                                     node.title  \
# 0                                                                      Progressive open source
# 1         Open source application spaces: the 5th workshop on open source software engineering
# 2  Reusing Open-Source Software and Practices: The Impact of Open-Source on Commercial Vendors
# 3                                                Software architecture in an open source world
# 4                                                        From Research Software to Open Source
# 5                                                     Open courseware and open source software
# 6                                                       IBM's pragmatic embrace of open source
# 7                                                       When to release in open source project
# 8                                                       Increased security through open source
# 9                                                         A sociopolitical look at open source
#
#       score
# 0  4.251786
# 1  4.081271
# 2  4.071275
# 3  3.815273
# 4  3.784185
# 5  3.693338
# 6  3.689845
# 7  3.542871
# 8  3.515002
# 9  3.492101

# %% [markdown]
# Here is a query to find the authors that have published the most articles on 'open source':
# 这里有一个查询，可以找到在“开放源码”上发表文章最多的作者:

# %%
query = """
CALL db.index.fulltext.queryNodes("articles", "open source")
YIELD node, score
MATCH (node)-[:AUTHOR]->(author)
RETURN author.name, sum(score) AS totalScore, collect(node.title) AS articles
ORDER BY totalScore DESC
LIMIT 20
 
"""

graph.run(query).to_data_frame()
# Out:
#                                                                                                articles  \
# 0   [Open source application spaces: the 5th workshop on open source software engineering, The 3rd w...
# 1   [Open source application spaces: the 5th workshop on open source software engineering, The 3rd w...
# 2   [Open source application spaces: the 5th workshop on open source software engineering, The futur...
# 3   [Open source-style collaborative development practices in commercial projects using GitHub, Mach...
# 4   [Open source application spaces: the 5th workshop on open source software engineering, The 3rd w...
# 5   [A case study of a corporate open source development model, Managing a corporate open source sof...
# 6   [Machine learning-based detection of open source license exceptions, Recommending source code fo...
# 7   [Understanding broadcast based peer review on open source software projects, Peer Review on Open...
# 8   [Understanding broadcast based peer review on open source software projects, Peer Review on Open...
# 9   [An automated tool for generating change report from open-source software, Cross project change ...
# 10  [Risk assessment in open source systems, QuESo a quality model for open source software ecosyste...
# 11                       [A sociopolitical look at open source, A look at the economics of open source]
# 12  [A case study of a corporate open source development model, Managing a corporate open source sof...
# 13  [A case study of a corporate open source development model, Managing a corporate open source sof...
# 14  [The 3rd workshop on open source software engineering, Collaboration, conflict and control: the ...
# 15  [Disseminating architectural knowledge on open-source projects: a case study of the book "archit...
# 16  [Where does this code come from and where does it go? - integrated code history tracker for open...
# 17  [Open implementation design guidelines, A degree-of-knowledge model to capture source code famil...
# 18  [Toward an understanding of the motivation of open source software developers, A case study of t...
# 19  [The hard life of open source software project newcomers, Overcoming open source project entry b...
#
#                 author.name  totalScore
# 0          Brian Fitzgerald   16.119015
# 1             Joseph Feller   16.011879
# 2              Walt Scacchi   10.730826
# 3          Daniel M. German   10.686845
# 4           Scott A. Hissam   10.641744
# 5         James D. Herbsleb   10.475500
# 6          Denys Poshyvanyk    8.906547
# 7   Margaret-Anne D. Storey    8.180790
# 8            Peter C. Rigby    7.648662
# 9          Ruchika Malhotra    7.132015
# 10            Xavier Franch    7.117475
# 11          Robert L. Glass    6.984201
# 12            Anita Garvert    6.689267
# 13         Vijay K. Gurbani    6.689267
# 14         Karim R. Lakhani    6.560473
# 15      Martin P. Robillard    6.413872
# 16            Katsuro Inoue    6.189850
# 17           Gail C. Murphy    6.134493
# 18          Kouichi Kishida    5.562843
# 19     Marco Aurélio Gerosa    5.490760

# %% [markdown]
# Next, use full text search and Personalized PageRank to find interesting articles for different authors:
#     接下来，使用全文搜索和个性化的PageRank为不同的作者找到有趣的文章:

# %%
query = """
MATCH (a:Author {name: $author})<-[:AUTHOR]-(article)-[:CITED]->(other)
WITH a, collect(article) + collect(other) AS sourceNodes
CALL algo.pageRank.stream(
  'CALL db.index.fulltext.queryNodes("articles", $searchTerm)
   YIELD node, score
   RETURN id(node) as id',
  'MATCH (a1:Article)-[:CITED]->(a2:Article) 
   RETURN id(a1) as source,id(a2) as target', 
  {sourceNodes: sourceNodes,graph:'cypher', params: {searchTerm: $searchTerm}})
YIELD nodeId, score
WITH algo.getNodeById(nodeId) AS n, score
WHERE not(exists((a)<-[:AUTHOR]-(n))) AND score > 0
RETURN n.title as article, score, [(n)-[:AUTHOR]->(author) | author.name][..5] AS authors
order by score desc limit 10
"""

params = {"author": "Tao Xie", "searchTerm": "open source"}
graph.run(query, params).to_data_frame()
# Out:
#                                                                                                article  \
# 0                                             Static detection of cross-site scripting vulnerabilities
# 1                Concern graphs: finding and describing concerns using structural program dependencies
# 2                                             Characterizing logging practices in open-source software
# 3                        Automated, contract-based user testing of commercial-off-the-shelf components
# 4                                                                              Who should fix this bug
# 5                                                Conceptual module querying for software reengineering
# 6                                                                          Semantics-based code search
# 7                                        Bandera: extracting finite-state models from Java source code
# 8  AsDroid: detecting stealthy behaviors in Android applications by user interface and program beha...
# 9                                                                     EXSYST: search-based GUI testing
#
#                                                                              authors  \
# 0                                                     [Zhendong Su, Gary Wassermann]
# 1                                              [Gail C. Murphy, Martin P. Robillard]
# 2                                            [Ding Yuan, Soyeon Park, Yuanyuan Zhou]
# 3                                  [Lionel C. Briand, Yvan Labiche, Michal M. Sówka]
# 4                                          [Lyndon Hiew, John Anvik, Gail C. Murphy]
# 5                                            [Gail C. Murphy, Elisa L. A. Baniassad]
# 6                                                                  [Steven P. Reiss]
# 7  [Matthew B. Dwyer, Hongjun Zheng, James C. Corbett, Shawn Laubach, John Hatcliff]
# 8                      [Lin Tan, Jianjun Huang, Xiangyu Zhang, Bin Liang, Peng Wang]
# 9                                     [Andreas Zeller, Gordon Fraser, Florian Gross]
#
#       score
# 0  0.385875
# 1  0.277500
# 2  0.277500
# 3  0.277500
# 4  0.277500
# 5  0.235875
# 6  0.150000
# 7  0.150000
# 8  0.150000
# 9  0.127500

# %% [markdown]
# Execute the same query with a different author:
#     使用不同的作者执行相同的查询:

# %%
params = {"author": "Marco Aurélio Gerosa", "searchTerm": "open source"}
graph.run(query, params).to_data_frame()
# Out:
#                                                                                               article  \
# 0                        Toward an understanding of the motivation of open source software developers
# 1                                      Hipikat: recommending pertinent software development artifacts
# 2                                     Version Sensitive Editing: Change History as a Programming Tool
# 3                                Which bug should I fix: helping new developers onboard a new project
# 4  Tesseract: Interactive visual exploration of socio-technical relationships in software development
# 5                 Role Migration and Advancement Processes in OSSD Projects: A Comparative Case Study
# 6                                        Does the initial environment impact the future of developers
# 7       Unifying artifacts and activities in a visual tool for distributed software development teams
# 8                                 A case study of open source software development: the Apache server
# 9          A case study of the evolution of Jun: an object-oriented open-source 3D multimedia library
#
#                                                                             authors  \
# 0                                                      [Yunwen Ye, Kouichi Kishida]
# 1                                                  [Gail C. Murphy, Davor Cubranic]
# 2                                                                 [David L. Atkins]
# 3                                                       [Jianguo Wang, Anita Sarma]
# 4              [Anita Sarma, Larry Maccherone, Patrick Wagstrom, James D. Herbsleb]
# 5                                                      [Walt Scacchi, Chris Jensen]
# 6                                                     [Minghui Zhou, Audris Mockus]
# 7                                                     [Jon Froehlich, Paul Dourish]
# 8                                  [James D. Herbsleb, Audris Mockus, Roy Fielding]
# 9  [Yoshiyuki Nishinaka, Atsushi Aoki, Kouichi Kishida, Y. Yamamoto, Kaoru Hayashi]
#
#       score
# 0  0.388425
# 1  0.322429
# 2  0.274065
# 3  0.239250
# 4  0.203363
# 5  0.175500
# 6  0.175500
# 7  0.172858
# 8  0.110054
# 9  0.110054
